# %%
def c_to_f(c):
    return (c*9/5)+32

def f_to_c(f):
    return(f-32)*5/9

print(c_to_f(0))
print(c_to_f(100))
print(f_to_c(98.6))
# Out:
# 32.0
# 212.0
# 37.0

# %%
def add(a,b): return a+b
def sub(a,b): return a-b
def mul(a,b): return a*b
def div(a,b): return a/b if b!=0 else"Error:divde by Zero"

print(add(10, 5))
print(sub(10,5))
print(mul(10,5))
print(div(10,0))
# Out:
# 15
# 5
# 50
# Error:divde by Zero
