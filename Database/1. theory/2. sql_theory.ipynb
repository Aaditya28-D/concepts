# %% [markdown]
# ### 1. **Basic SELECT Queries**
#    - Selecting all columns with `SELECT *`.
#    - Selecting specific columns.
#
# ### 2. **Filtering Data with WHERE**
#    - Using numerical and text conditions.
#    - Combining conditions with logical operators like `AND` and `OR`.
#
# ### 3. **Sorting Results with ORDER BY**
#    - Sorting by a single column and multiple columns.
#    - Using ascending (`ASC`) and descending (`DESC`) order.
#
# ### 4. **Joining Tables**
#    - Using `INNER JOIN` to combine rows from two or more tables based on a related column.
#    - Complex joins including conditions in the join.
#
# ### 5. **Grouping Data with GROUP BY**
#    - Aggregating data with functions like `COUNT`, `SUM`, `AVG`, `MIN`, and `MAX`.
#    - Using the `GROUP BY` clause to group the result set by one or more columns.
#
# ### 6. **Filtering Groups with HAVING**
#    - Using the `HAVING` clause to filter groups based on aggregated results.
#
# ### 7. **Using Subqueries**
#    - In various clauses such as `WHERE`, `SELECT`, `FROM`, and `JOIN`.
#
# ### 8. **Set Operations**
#    - Concepts like `UNION`, `INTERSECT`, and `EXCEPT` to combine results from multiple queries.
#
# ### 9. **Data Modification Statements**
#    - `INSERT` to add new rows to tables.
#    - `UPDATE` to modify existing data.
#    - `DELETE` to remove data.
#
# ### 10. **Transaction Control**
#    - Concepts of transactions, including starting and committing transactions.
#
# ### 11. **Using Indexes and Keys**
#    - Understanding primary keys and how indexes can improve query performance.
#
# ### 12. **Data Types and Schema Design**
#    - Discussing various data types and the importance of schema design in database management.
#
# ### 13. **Views**
#    - Creating and using views as virtual tables.
#
# ### 14. **Functions and Stored Procedures**
#    - Using built-in SQL functions and creating custom stored procedures for reusable logic.
#
# ### 15. **Date and Time Handling**
#    - Manipulating and formatting date and time data in SQL.
#
# ### 16. **Conditional Expressions and Case Statements**
#    - Using `CASE` statements for conditional logic within queries.
#
# These topics cover a wide range of foundational and intermediate SQL concepts, essential for querying, manipulating, and managing data effectively in relational databases. If you're interested in exploring any specific areas further or need examples and detailed explanations on any topic, let me know!

# %% [markdown]
# ### Subqueries type
#
# 1. **Subqueries in the WHERE Clause**
# 2. **Subqueries in the SELECT Clause**
# 3. **Correlated Subqueries**
# 4. **Subqueries in the FROM Clause**
# 5. **Subqueries in the JOIN Condition**
# 6. **Subqueries in the HAVING Clause**
# 7. **EXISTS and NOT EXISTS**
# 8. **IN and NOT IN**
# 9. **Subqueries with ANY and ALL**
# 10. **Scalar Subqueries** (return a single value)
# 11. **Row Subqueries** (return a single row)
# 12. **Table Subqueries** (return a table)
# 13. **Nested Subqueries** (subqueries within subqueries)
# 14. **Recursive Subqueries** (used particularly with recursive common table expressions)
# 15. **Subqueries as Derived Tables**
# 16. **Subqueries in INSERT Statements**
# 17. **Subqueries in UPDATE Statements**
# 18. **Subqueries in DELETE Statements**
#
# These subquery types cover a broad range of functionalities, from basic data filtering and selection to more complex recursive queries and dynamic data manipulation. Each type enhances SQL's ability to handle complex datasets and perform sophisticated data operations. If you decide to dive deeper into any specific type or need examples, feel free to ask!
